# %% [markdown]
# # TCAMP: Google Colab + GitHub Setup
# Setup environment for Colab execution. Mounts Google Drive for persistent storage, clones the GitHub repository, and sets up the GPU environment.

# %%
from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Navigate to working directory
os.chdir('/content/drive/MyDrive')

# %%
# 3. Clone the GitHub Repository
# !git clone https://github.com/humanai-foundation/ISSR.git

# %%
# 4. Navigate to project root
PROJECT_PATH = "/content/drive/MyDrive/ISSR/ISSR_TCAMP_TeamCommunicationAnalysisAndProcessingPipeline_VennelaVarshiniAnasoori"
os.chdir(PROJECT_PATH)

# Pull latest changes from master
# !git pull

print(f"Current working directory: {os.getcwd()}")

# %%
# 5. Install required dependencies
# !pip install -r requirements.txt

# %%
import os

# 6. Set Hugging Face Token
os.environ["HF_TOKEN"] = "YOUR_HF_TOKEN_HERE"

# 7. Execute batch evaluation
# !python evaluate_batch.py --condition 1
