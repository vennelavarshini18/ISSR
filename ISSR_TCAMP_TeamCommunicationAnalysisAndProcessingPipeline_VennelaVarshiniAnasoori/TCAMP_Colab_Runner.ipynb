# %% [markdown]
# # TCAMP: Colab GPU Execution via GitHub

# %%
import os

PROJECT_PATH = '/content/ISSR/ISSR_TCAMP_TeamCommunicationAnalysisAndProcessingPipeline_VennelaVarshiniAnasoori'
os.chdir(PROJECT_PATH)

# %%
#Install dependencies
# !apt-get update && apt-get install -y rustc cargo

# %%
# !apt-get update && apt-get install -y ffmpeg

# %%
# !pip install -r requirements.txt

# %%
# !pip install git+https://github.com/m-bain/whisperx.git --no-deps

# %%
# Set Hugging Face Token (REQUIRED FOR PYANNOTE)
os.environ['HF_TOKEN'] = 'YOUR_HF_TOKEN_HERE'

# %%
import subprocess
import time

# !apt-get update && apt-get install -y zstd

# Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# Start the Ollama server in the background
subprocess.Popen(["ollama", "serve"])

# Give the server 15 seconds to wake up, then pull the model
time.sleep(15)
# !ollama pull llama3.2

# %%
#Example 
# Full Pipeline on AMI Corpus
# !python run_pipeline.py -i "screening_notebooks/sample_input_and_output_files/EN2002a.wav" -o "observations/outputs/Blog_Sample_AMI" --run-qc --run-analytics --phase all
