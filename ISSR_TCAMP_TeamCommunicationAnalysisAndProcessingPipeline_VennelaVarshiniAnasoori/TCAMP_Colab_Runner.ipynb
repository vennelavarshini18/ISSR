# %% [markdown]
# # TCAMP: Colab GPU Execution via GitHub

# %%
import os

PROJECT_PATH = '/content/ISSR/ISSR_TCAMP_TeamCommunicationAnalysisAndProcessingPipeline_VennelaVarshiniAnasoori'
os.chdir(PROJECT_PATH)

# %%
# 3. Install dependencies
# !pip install -r requirements.txt

# %%
# 4. Set Hugging Face Token (REQUIRED FOR PYANNOTE)
os.environ['HF_TOKEN'] = 'YOUR_HF_TOKEN_HERE'

# 5. Run Full Phase 3 Pipeline on Full AMI File
# !python run_pipeline.py --input screening_notebooks/sample_input_and_output_files/EN2002a.wav --transcription-model large-v2 --transcription-device cuda --transcription-compute float16

# %%
# View output
with open('observations/outputs/transcript_EN2002a.txt', 'r') as f:
    print(f.read())
